# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/product_dataset_1000.csv")

# %%
df.head()
df.info()
df.describe()
df.shape
df.isnull().sum()
df.dtypes

# %%
df['TotalValue'] = df['Price'] * df['Quantity']

# %%
df['Price'].mean()
df['Category'].value_counts()
